# %%
import pandas as pd

# %%
df=pd.read_csv('breast-cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df.drop('id',axis=1)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           M        17.99         10.38          122.80     1001.0
# 1           M        20.57         17.77          132.90     1326.0
# 2           M        19.69         21.25          130.00     1203.0
# 3           M        11.42         20.38           77.58      386.1
# 4           M        20.29         14.34          135.10     1297.0
# ..        ...          ...           ...             ...        ...
# 564         M        21.56         22.39          142.00     1479.0
# 565         M        20.13         28.25          131.20     1261.0
# 566         M        16.60         28.08          108.30      858.1
# 567         M        20.60         29.33          140.10     1265.0
# 568         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df['diagnosis']=df['diagnosis'].map({'M':1,'B':0})

# %%
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1        17.99         10.38          122.80
# 1      842517          1        20.57         17.77          132.90
# 2    84300903          1        19.69         21.25          130.00
# 3    84348301          1        11.42         20.38           77.58
# 4    84358402          1        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          1        21.56         22.39          142.00
# 565    926682          1        20.13         28.25          131.20
# 566    926954          1        16.60         28.08          108.30
# 567    927241          1        20.60         29.33          140.10
# 568     92751          0         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
x=df[['radius_mean','texture_mean']]
y=df['diagnosis']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train)
x_test_scaled=scaler.transform(x_test)

# %%
from sklearn.svm import SVC

# %%
svm_linear=SVC(kernel='linear',C=0.1)
svm_linear.fit(x_train_scaled,y_train)
# Out:
# SVC(C=0.1, kernel='linear')

# %%
svm_rbf=SVC(kernel='rbf',C=0.1,gamma='scale')
svm_rbf.fit(x_train_scaled,y_train)
# Out:
# SVC(C=0.1)

# %%
import matplotlib.pyplot as plt
import numpy as np

def simple_plot_svm(model,x, y, title):
   
    plt.scatter(x[:, 0], x[:, 1], c=y, edgecolors='k')
    
    x_ = np.linspace(x[:, 0].min() - 1, x[:, 0].max() + 1, 500)
    y_ = np.linspace(x[:, 1].min() - 1, x[:, 1].max() + 1, 500)
    xx, yy = np.meshgrid(x_, y_)
    grid = np.c_[xx.ravel(), yy.ravel()]
    
    Z = model.predict(grid).reshape(xx.shape)
    
    plt.contourf(xx, yy, Z, alpha=0.3, cmap='coolwarm')
    plt.xlabel('radius_mean')
    plt.ylabel('texture_mean')
    plt.title(title)
    plt.show()

simple_plot_svm(svm_linear, x_train_scaled, y_train, "SVM - Linear Kernel")
simple_plot_svm(svm_rbf, x_train_scaled, y_train, "SVM - RBF Kernel")

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'C': [0.1, 1, 10, 100, 1000], 
    'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
    'kernel': ['rbf']
}

grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3) 
grid.fit(x_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.875 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.900 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.963 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.886 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.912 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.938 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.835 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.873 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.637 total time=   0.0s
# ...

# %%
print("Best Parameters:", grid.best_params_)
print("Best Cross-Validation Score:", grid.best_score_)
# Out:
# Best Parameters: {'C': 100, 'gamma': 0.01, 'kernel': 'rbf'}
# Best Cross-Validation Score: 0.9018354430379747

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

best_model = grid.best_estimator_

y_pred = best_model.predict(x_test_scaled)

print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("Test Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[102   6]
#  [ 10  53]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.94      0.93       108
#            1       0.90      0.84      0.87        63
#
#     accuracy                           0.91       171
#    macro avg       0.90      0.89      0.90       171
# weighted avg       0.91      0.91      0.91       171
#
# Test Accuracy: 0.9064327485380117

# %%
from sklearn.model_selection import cross_val_score

# %%
svm_rbf = SVC(kernel='rbf', C=1.0, gamma='scale')
cv_scores = cross_val_score(svm_rbf,x, y, cv=5)

print("Cross-Validation Scores for SVM (RBF):", cv_scores)
print("Mean CV Score:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores for SVM (RBF): [0.85087719 0.87719298 0.9122807  0.93859649 0.90265487]
# Mean CV Score: 0.8963204471355379
